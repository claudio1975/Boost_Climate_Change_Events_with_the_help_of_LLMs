# %% [markdown]
# ### Data Source

# %% [markdown]
# https://www.ncei.noaa.gov/pub/data/swdi/stormevents/csvfiles/ -- csv files picked up
# https://www.ncei.noaa.gov/access/metadata/landing-page/bin/iso?id=gov.noaa.ncdc:C00510 -- Storm Event Database
# https://www.kaggle.com/datasets/landfallmotto/billiondollar-weather-and-climate-disasters/data -- Aggregate Database from Kaggle
# https://www.ncei.noaa.gov/access/billions/ -- nooa article

# %% [markdown]
# ### Datasets

# %%
import pandas as pd

# %%
df1=pd.read_csv('StormEvents_details-ftp_v1.0_d1950_c20210803.csv',low_memory=False)

# %%
df2=pd.read_csv('StormEvents_details-ftp_v1.0_d1951_c20210803.csv',low_memory=False)

# %%
df3=pd.read_csv('StormEvents_details-ftp_v1.0_d1952_c20210803.csv',low_memory=False)

# %%
df4=pd.read_csv('StormEvents_details-ftp_v1.0_d1953_c20210803.csv',low_memory=False)

# %%
df5=pd.read_csv('StormEvents_details-ftp_v1.0_d1954_c20210803.csv',low_memory=False)

# %%
df6=pd.read_csv('StormEvents_details-ftp_v1.0_d1955_c20210803.csv',low_memory=False)

# %%
df7=pd.read_csv('StormEvents_details-ftp_v1.0_d1956_c20210803.csv',low_memory=False)

# %%
df8=pd.read_csv('StormEvents_details-ftp_v1.0_d1957_c20210803.csv',low_memory=False)

# %%
df9=pd.read_csv('StormEvents_details-ftp_v1.0_d1958_c20210803.csv',low_memory=False)

# %%
df10=pd.read_csv('StormEvents_details-ftp_v1.0_d1959_c20210803.csv',low_memory=False)

# %%
df11=pd.read_csv('StormEvents_details-ftp_v1.0_d1960_c20210803.csv',low_memory=False)

# %%
df12=pd.read_csv('StormEvents_details-ftp_v1.0_d1961_c20210803.csv',low_memory=False)

# %%
df13=pd.read_csv('StormEvents_details-ftp_v1.0_d1962_c20210803.csv',low_memory=False)

# %%
df14=pd.read_csv('StormEvents_details-ftp_v1.0_d1963_c20210803.csv',low_memory=False)

# %%
df15=pd.read_csv('StormEvents_details-ftp_v1.0_d1964_c20210803.csv',low_memory=False)

# %%
df16=pd.read_csv('StormEvents_details-ftp_v1.0_d1965_c20210803.csv',low_memory=False)

# %%
df17=pd.read_csv('StormEvents_details-ftp_v1.0_d1966_c20210803.csv',low_memory=False)

# %%
df18=pd.read_csv('StormEvents_details-ftp_v1.0_d1967_c20210803.csv',low_memory=False)

# %%
df19=pd.read_csv('StormEvents_details-ftp_v1.0_d1968_c20210803.csv',low_memory=False)

# %%
df20=pd.read_csv('StormEvents_details-ftp_v1.0_d1969_c20210803.csv',low_memory=False)

# %%
df21=pd.read_csv('StormEvents_details-ftp_v1.0_d1970_c20210803.csv',low_memory=False)

# %%
df22=pd.read_csv('StormEvents_details-ftp_v1.0_d1971_c20210803.csv',low_memory=False)

# %%
df23=pd.read_csv('StormEvents_details-ftp_v1.0_d1972_c20220425.csv',low_memory=False)

# %%
df24=pd.read_csv('StormEvents_details-ftp_v1.0_d1973_c20220425.csv',low_memory=False)

# %%
df25=pd.read_csv('StormEvents_details-ftp_v1.0_d1974_c20220425.csv',low_memory=False)

# %%
df26=pd.read_csv('StormEvents_details-ftp_v1.0_d1975_c20220425.csv',low_memory=False)

# %%
df27=pd.read_csv('StormEvents_details-ftp_v1.0_d1976_c20220425.csv',low_memory=False)

# %%
df28=pd.read_csv('StormEvents_details-ftp_v1.0_d1977_c20220425.csv',low_memory=False)

# %%
df29=pd.read_csv('StormEvents_details-ftp_v1.0_d1978_c20220425.csv',low_memory=False)

# %%
df30=pd.read_csv('StormEvents_details-ftp_v1.0_d1979_c20220425.csv',low_memory=False)

# %%
df31=pd.read_csv('StormEvents_details-ftp_v1.0_d1980_c20220425.csv',low_memory=False)

# %%
df32=pd.read_csv('StormEvents_details-ftp_v1.0_d1981_c20220425.csv',low_memory=False)

# %%
df33=pd.read_csv('StormEvents_details-ftp_v1.0_d1982_c20220425.csv',low_memory=False)

# %%
df34=pd.read_csv('StormEvents_details-ftp_v1.0_d1983_c20220425.csv',low_memory=False)

# %%
df35=pd.read_csv('StormEvents_details-ftp_v1.0_d1984_c20220425.csv',low_memory=False)

# %%
df36=pd.read_csv('StormEvents_details-ftp_v1.0_d1985_c20220425.csv',low_memory=False)

# %%
df37=pd.read_csv('StormEvents_details-ftp_v1.0_d1986_c20220425.csv',low_memory=False)

# %%
df38=pd.read_csv('StormEvents_details-ftp_v1.0_d1987_c20220425.csv',low_memory=False)

# %%
df39=pd.read_csv('StormEvents_details-ftp_v1.0_d1988_c20220425.csv',low_memory=False)

# %%
df40=pd.read_csv('StormEvents_details-ftp_v1.0_d1989_c20220425.csv',low_memory=False)

# %%
df41=pd.read_csv('StormEvents_details-ftp_v1.0_d1990_c20220425.csv',low_memory=False)

# %%
df42=pd.read_csv('StormEvents_details-ftp_v1.0_d1991_c20220425.csv',low_memory=False)

# %%
df43=pd.read_csv('StormEvents_details-ftp_v1.0_d1992_c20220425.csv',low_memory=False)

# %%
df44=pd.read_csv('StormEvents_details-ftp_v1.0_d1993_c20220425.csv',low_memory=False)

# %%
df45=pd.read_csv('StormEvents_details-ftp_v1.0_d1994_c20220425.csv',low_memory=False)

# %%
df46=pd.read_csv('StormEvents_details-ftp_v1.0_d1995_c20220425.csv',low_memory=False)

# %%
df47=pd.read_csv('StormEvents_details-ftp_v1.0_d1996_c20220425.csv',low_memory=False)

# %%
df48=pd.read_csv('StormEvents_details-ftp_v1.0_d1997_c20220425.csv',low_memory=False)

# %%
df49=pd.read_csv('StormEvents_details-ftp_v1.0_d1998_c20220425.csv',low_memory=False)

# %%
df50=pd.read_csv('StormEvents_details-ftp_v1.0_d1999_c20220425.csv',low_memory=False)

# %%
df51=pd.read_csv('StormEvents_details-ftp_v1.0_d2000_c20220425.csv',low_memory=False)

# %%
df52=pd.read_csv('StormEvents_details-ftp_v1.0_d2001_c20220425.csv',low_memory=False)

# %%
df53=pd.read_csv('StormEvents_details-ftp_v1.0_d2002_c20220425.csv',low_memory=False)

# %%
df54=pd.read_csv('StormEvents_details-ftp_v1.0_d2003_c20220425.csv',low_memory=False)

# %%
df55=pd.read_csv('StormEvents_details-ftp_v1.0_d2004_c20220425.csv',low_memory=False)

# %%
df56=pd.read_csv('StormEvents_details-ftp_v1.0_d2005_c20220425.csv',low_memory=False)

# %%
df57=pd.read_csv('StormEvents_details-ftp_v1.0_d2006_c20220425.csv', low_memory=False)

# %%
df58=pd.read_csv('StormEvents_details-ftp_v1.0_d2007_c20220425.csv',low_memory=False)

# %%
df59=pd.read_csv('StormEvents_details-ftp_v1.0_d2008_c20220425.csv',low_memory=False)

# %%
df60=pd.read_csv('StormEvents_details-ftp_v1.0_d2009_c20220425.csv',low_memory=False)

# %%
df61=pd.read_csv('StormEvents_details-ftp_v1.0_d2010_c20220425.csv',low_memory=False)

# %%
df62=pd.read_csv('StormEvents_details-ftp_v1.0_d2011_c20230417.csv',low_memory=False)

# %%
df63=pd.read_csv('StormEvents_details-ftp_v1.0_d2012_c20221216.csv',low_memory=False)

# %%
df64=pd.read_csv('StormEvents_details-ftp_v1.0_d2013_c20230118.csv',low_memory=False)

# %%
df65=pd.read_csv('StormEvents_details-ftp_v1.0_d2014_c20230330.csv',low_memory=False)

# %%
df66=pd.read_csv('StormEvents_details-ftp_v1.0_d2015_c20220425.csv',low_memory=False)

# %%
df67=pd.read_csv('StormEvents_details-ftp_v1.0_d2016_c20220719.csv',low_memory=False)

# %%
df68=pd.read_csv('StormEvents_details-ftp_v1.0_d2017_c20230317.csv',low_memory=False)

# %%
df69=pd.read_csv('StormEvents_details-ftp_v1.0_d2018_c20230616.csv',low_memory=False)

# %%
df70=pd.read_csv('StormEvents_details-ftp_v1.0_d2019_c20231017.csv',low_memory=False)

# %%
df71=pd.read_csv('StormEvents_details-ftp_v1.0_d2020_c20230927.csv',low_memory=False)

# %%
df72=pd.read_csv('StormEvents_details-ftp_v1.0_d2021_c20231017.csv',low_memory=False)

# %%
df73=pd.read_csv('StormEvents_details-ftp_v1.0_d2022_c20231017.csv',low_memory=False)

# %% [markdown]
# ### Merging datasets

# %%
dftot=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,
                 df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,
                df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,df51,df52,df53,df54,df55,df56,df57,df58,df59,df60,
                df61,df62,df63,df64,df65,df66,df67,df68,df69,df70,df71,df72,df73], axis=0)

# %%
dftot.head(10)
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           195004         28        1445         195004       28      1445
# 1           195004         29        1530         195004       29      1530
# 2           195007          5        1800         195007        5      1800
# 3           195007          5        1830         195007        5      1830
# 4           195007         24        1440         195007       24      1440
# 5           195008         29        1600         195008       29      1600
# 6           195011          4        1700         195011        4      1700
# 7           195011          4        1730         195011        4      1730
# 8           195009         15        1745         195009       15      1745
# 9           195009         16         130         195009       16       130
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0         NaN  10096222      OKLAHOMA        40.0  ...        0.0         NaN
# 1         NaN  10120412         TEXAS        48.0  ...        0.0         NaN
# 2         NaN  10104927  PENNSYLVANIA        42.0  ...        0.0         NaN
# 3         NaN  10104928  PENNSYLVANIA        42.0  ...        0.0         NaN
# 4         NaN  10104929  PENNSYLVANIA        42.0  ...        0.0         NaN
# 5         NaN  10104930  PENNSYLVANIA        42.0  ...        0.0         NaN
# 6         NaN  10104931  PENNSYLVANIA        42.0  ...        0.0         NaN
# 7         NaN  10104932  PENNSYLVANIA        42.0  ...        0.0         NaN
# 8         NaN  10099490      OKLAHOMA        40.0  ...        0.0         NaN
# 9         NaN  10099491      OKLAHOMA        40.0  ...        0.0         NaN
#
#   END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON EPISODE_NARRATIVE  \
# 0          NaN     35.12     -99.20   35.17  -99.20               NaN
# 1          NaN     31.90     -98.60   31.73  -98.60               NaN
# 2          NaN     40.58     -75.70   40.65  -75.47               NaN
# 3          NaN     40.60     -76.75     NaN     NaN               NaN
# 4          NaN     41.63     -79.68     NaN     NaN               NaN
# 5          NaN     40.22     -75.00     NaN     NaN               NaN
# 6          NaN     40.20     -76.12   40.27  -76.07               NaN
# 7          NaN     40.27     -76.07   40.40  -75.93               NaN
# 8          NaN     35.00     -96.25   35.07  -96.17               NaN
# 9          NaN     34.83     -95.85     NaN     NaN               NaN
#
#   EVENT_NARRATIVE DATA_SOURCE
# 0             NaN         PUB
# 1             NaN         PUB
# 2             NaN         PUB
# 3             NaN         PUB
# 4             NaN         PUB
# 5             NaN         PUB
# 6             NaN         PUB
# 7             NaN         PUB
# 8             NaN         PUB
# 9             NaN         PUB
#
# [10 rows x 51 columns]

# %%
dftot['EVENT_TYPE'].describe().T
# Out:
# count               1794914
# unique                   70
# top       Thunderstorm Wind
# freq                 501183
# Name: EVENT_TYPE, dtype: object

# %%
dftot['EVENT_TYPE'] = dftot['EVENT_TYPE'].str.title()

# %% [markdown]
# #### Flood_Event_Type

# %%
dftot_flood = dftot[dftot['EVENT_TYPE'].isin(['Flood'])]

# %%
dftot_flood.shape
# Out:
# (62462, 51)

# %%
dftot_flood.head(10)
# Out:
#      BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 25            199601         24        1200         199601       24      1200
# 34            199601         22         700         199601       31      1159
# 44            199601         26        2330         199601       27       630
# 164           199601         22         700         199601       31      1159
# 189           199601         22         700         199601       31      1159
# 267           199601         12        1800         199601       12      2100
# 311           199602         18           1         199602       21      1600
# 312           199601         12        1800         199601       12      2100
# 313           199601         12        1900         199601       12      2100
# 314           199601         12        1900         199601       12      2100
#
#      EPISODE_ID  EVENT_ID           STATE  STATE_FIPS  ...  END_RANGE  \
# 25    1000569.0   5536059         INDIANA        18.0  ...        NaN
# 34    1002242.0   5549485        KENTUCKY        21.0  ...        NaN
# 44    2404288.0   5537263  NORTH CAROLINA        37.0  ...        NaN
# 164   1002242.0   5549489        KENTUCKY        21.0  ...        NaN
# 189   1002242.0   5549484        KENTUCKY        21.0  ...        NaN
# 267   1013909.0   5561921      NEW JERSEY        34.0  ...        NaN
# 311   2404445.0   5537541      CALIFORNIA         6.0  ...        NaN
# 312   2040562.0   5561922      NEW JERSEY        34.0  ...        NaN
# 313   2040563.0   5561923     CONNECTICUT         9.0  ...        NaN
# 314   2040564.0   5561924     CONNECTICUT         9.0  ...        NaN
#
#     END_AZIMUTH        END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON  \
# 25          NaN                 NaN       NaN        NaN     NaN     NaN
# 34          NaN                 NaN       NaN        NaN     NaN     NaN
# 44          NaN                 NaN       NaN        NaN     NaN     NaN
# 164         NaN                 NaN       NaN        NaN     NaN     NaN
# 189         NaN                 NaN       NaN        NaN     NaN     NaN
# 267         NaN          COUNTYWIDE       NaN        NaN     NaN     NaN
# 311         NaN                 NaN       NaN        NaN     NaN     NaN
# 312         NaN     EASTERN PASSAIC       NaN        NaN     NaN     NaN
# 313         NaN  SOUTHERN FAIRFIELD       NaN        NaN     NaN     NaN
# 314         NaN  SOUTHERN MIDDLESEX       NaN        NaN     NaN     NaN
#
#                                      EPISODE_NARRATIVE EVENT_NARRATIVE  \
# 25   On the 23rd, many areas received around an inc...             NaN
# 34   Snowmelt and heavy rain caused widespread floo...             NaN
# 44   Prolonged rain became heavier following the ic...             NaN
# 164  Snowmelt and heavy rain caused widespread floo...             NaN
# 189  Snowmelt and heavy rain caused widespread floo...             NaN
# 267                                                NaN             NaN
# 311  Heavy rains from the 18th to the 21st, includi...             NaN
# 312                                                NaN             NaN
# 313                                                NaN             NaN
# 314                                                NaN             NaN
#
#     DATA_SOURCE
# 25          PDC
# 34          PDC
# 44          PDC
# 164         PDC
# 189         PDC
# 267         PDC
# 311         PDC
# 312         PDC
# 313         PDC
# 314         PDC
#
# [10 rows x 51 columns]

# %% [markdown]
# ### Missing values

# %%
missing = dftot_flood.isnull().sum()/dftot_flood.shape[0]*100
missing
# Out:
# BEGIN_YEARMONTH         0.000000
# BEGIN_DAY               0.000000
# BEGIN_TIME              0.000000
# END_YEARMONTH           0.000000
# END_DAY                 0.000000
# END_TIME                0.000000
# EPISODE_ID              0.000000
# EVENT_ID                0.000000
# STATE                   0.000000
# STATE_FIPS              0.000000
# YEAR                    0.000000
# MONTH_NAME              0.000000
# EVENT_TYPE              0.000000
# CZ_TYPE                 0.000000
# CZ_FIPS                 0.000000
# CZ_NAME                 0.000000
# WFO                     0.000000
# BEGIN_DATE_TIME         0.000000
# CZ_TIMEZONE             0.000000
# END_DATE_TIME           0.000000
# INJURIES_DIRECT         0.000000
# INJURIES_INDIRECT       0.000000
# DEATHS_DIRECT           0.000000
# DEATHS_INDIRECT         0.000000
# DAMAGE_PROPERTY        23.473472
# DAMAGE_CROPS           30.596202
# SOURCE                  8.774935
# MAGNITUDE              99.980788
# MAGNITUDE_TYPE        100.000000
# FLOOD_CAUSE            33.894208
# CATEGORY              100.000000
# TOR_F_SCALE           100.000000
# TOR_LENGTH            100.000000
# TOR_WIDTH             100.000000
# TOR_OTHER_WFO         100.000000
# TOR_OTHER_CZ_STATE    100.000000
# TOR_OTHER_CZ_FIPS     100.000000
# TOR_OTHER_CZ_NAME     100.000000
# BEGIN_RANGE            33.112933
# BEGIN_AZIMUTH          33.112933
# BEGIN_LOCATION         26.937978
# END_RANGE              33.112933
# END_AZIMUTH            33.112933
# END_LOCATION           26.937978
# BEGIN_LAT              31.185361
# BEGIN_LON              31.185361
# END_LAT                31.185361
# END_LON                31.185361
# EPISODE_NARRATIVE       8.947840
# EVENT_NARRATIVE        29.654830
# DATA_SOURCE             0.000000
# dtype: float64

# %% [markdown]
# ### Cleaning missing values on variables linked with flood

# %%
dftot_flood_cleaned=dftot_flood.dropna(subset = ['DAMAGE_PROPERTY','DAMAGE_CROPS','EPISODE_NARRATIVE','FLOOD_CAUSE',
                           'EVENT_NARRATIVE','BEGIN_RANGE','BEGIN_LOCATION','BEGIN_LON'])

# %%
dftot_flood_cleaned.shape
# Out:
# (38398, 51)

# %%
dftot_flood_cleaned.isnull().sum()/dftot_flood_cleaned.shape[0]*100
# Out:
# BEGIN_YEARMONTH         0.0
# BEGIN_DAY               0.0
# BEGIN_TIME              0.0
# END_YEARMONTH           0.0
# END_DAY                 0.0
# END_TIME                0.0
# EPISODE_ID              0.0
# EVENT_ID                0.0
# STATE                   0.0
# STATE_FIPS              0.0
# YEAR                    0.0
# MONTH_NAME              0.0
# EVENT_TYPE              0.0
# CZ_TYPE                 0.0
# CZ_FIPS                 0.0
# CZ_NAME                 0.0
# WFO                     0.0
# BEGIN_DATE_TIME         0.0
# CZ_TIMEZONE             0.0
# END_DATE_TIME           0.0
# INJURIES_DIRECT         0.0
# INJURIES_INDIRECT       0.0
# DEATHS_DIRECT           0.0
# DEATHS_INDIRECT         0.0
# DAMAGE_PROPERTY         0.0
# DAMAGE_CROPS            0.0
# SOURCE                  0.0
# MAGNITUDE             100.0
# MAGNITUDE_TYPE        100.0
# FLOOD_CAUSE             0.0
# CATEGORY              100.0
# TOR_F_SCALE           100.0
# TOR_LENGTH            100.0
# TOR_WIDTH             100.0
# TOR_OTHER_WFO         100.0
# TOR_OTHER_CZ_STATE    100.0
# TOR_OTHER_CZ_FIPS     100.0
# TOR_OTHER_CZ_NAME     100.0
# BEGIN_RANGE             0.0
# BEGIN_AZIMUTH           0.0
# BEGIN_LOCATION          0.0
# END_RANGE               0.0
# END_AZIMUTH             0.0
# END_LOCATION            0.0
# BEGIN_LAT               0.0
# BEGIN_LON               0.0
# END_LAT                 0.0
# END_LON                 0.0
# EPISODE_NARRATIVE       0.0
# EVENT_NARRATIVE         0.0
# DATA_SOURCE             0.0
# dtype: float64

# %%
dftot_flood_cleaned.head(10)
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 48621           200610         28        1400         200610       28
# 48661           200611         16        2000         200611       16
# 48662           200611         16        2349         200611       17
# 48663           200611         17         503         200611       17
# 48664           200611         17         503         200611       17
# 48688           200610         28        1500         200610       28
# 48689           200610         28        1400         200610       28
# 48728           200611         17         700         200611       18
# 48733           200612         14         700         200612       14
# 48734           200612         14         700         200612       15
#
#        END_TIME  EPISODE_ID  EVENT_ID          STATE  STATE_FIPS  ...  \
# 48621      1630       544.0      2161  MASSACHUSETTS        25.0  ...
# 48661      2200       836.0      4734       NEW YORK        36.0  ...
# 48662       528       836.0      3709       NEW YORK        36.0  ...
# 48663      1356       836.0      3718       NEW YORK        36.0  ...
# 48664      1356       836.0      3720       NEW YORK        36.0  ...
# 48688      1700       546.0      2189    CONNECTICUT         9.0  ...
# 48689      1630       544.0      2162  MASSACHUSETTS        25.0  ...
# 48728      2130       836.0      3741       NEW YORK        36.0  ...
# 48733      1500      1893.0      9312         OREGON        41.0  ...
# 48734      1500      1893.0      9313         OREGON        41.0  ...
#
#        END_RANGE END_AZIMUTH   END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT  \
# 48621        0.0           N         BOSTON     42.32     -71.07   42.32
# 48661        0.0           N   LITTLE FALLS     43.05     -74.87   43.05
# 48662        9.0          NW  ST JOHNSVILLE     43.09     -74.54   43.09
# 48663        0.0           N    TRIBES HILL     42.95     -74.30   42.95
# 48664       17.0          NW    SCHENECTADY     42.97     -73.68   42.97
# 48688        0.0           N    WILLIMANTIC     41.72     -72.22   41.72
# 48689        0.0           N        TAUNTON     41.90     -71.10   41.90
# 48728        4.0           W          GRANT     43.32     -74.97   43.32
# 48733        0.0           N      TILLAMOOK     45.45    -123.85   45.45
# 48734        0.0           N      BATTERSON     45.73    -123.75   45.73
#
#       END_LON                                  EPISODE_NARRATIVE  \
# 48621  -71.07  Low pressure intensified rapidly as it tracked...
# 48661  -74.87  A low pressure system developed over the lower...
# 48662  -74.54  A low pressure system developed over the lower...
# 48663  -74.30  A low pressure system developed over the lower...
# 48664  -73.68  A low pressure system developed over the lower...
# 48688  -72.22  Significant urban flooding impacted Windham Co...
# 48689  -71.10  Low pressure intensified rapidly as it tracked...
# 48728  -74.97  A low pressure system developed over the lower...
# 48733 -123.85  A series of very wet Pacific storms brought si...
# 48734 -123.75  A series of very wet Pacific storms brought si...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 48621  Significant urban flooding was reported throug...         CSV
# 48661  Flooding caused road closures on Route 5 near ...         CSV
# 48662  The Mohawk River at Little Falls exceeded its ...         CSV
# 48663  The Mohawk River at Tribes Hill exceeded its f...         CSV
# 48664  The Mohawk River at Tribes Hill exceeded its f...         CSV
# 48688  Significant urban flooding was reported in and...         CSV
# 48689  Significant urban flooding was reported in Tau...         CSV
# 48728  The West Canada Creek at Hinckley exceeded its...         CSV
# 48733  The Wilson River near Tillamook crested at 12....         CSV
# 48734  The Nehalem River near Foss was above flood st...         CSV
#
# [10 rows x 51 columns]

# %%
dftot_flood_cleaned = dftot_flood_cleaned.reset_index(drop=True)

# %%
dftot_flood_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38398 entries, 0 to 38397
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     38398 non-null  int64
#  1   BEGIN_DAY           38398 non-null  int64
#  2   BEGIN_TIME          38398 non-null  int64
#  3   END_YEARMONTH       38398 non-null  int64
#  4   END_DAY             38398 non-null  int64
#  5   END_TIME            38398 non-null  int64
#  6   EPISODE_ID          38398 non-null  float64
#  7   EVENT_ID            38398 non-null  int64
#  8   STATE               38398 non-null  object
#  9   STATE_FIPS          38398 non-null  float64
#  10  YEAR                38398 non-null  int64
#  11  MONTH_NAME          38398 non-null  object
#  12  EVENT_TYPE          38398 non-null  object
#  13  CZ_TYPE             38398 non-null  object
#  14  CZ_FIPS             38398 non-null  int64
#  15  CZ_NAME             38398 non-null  object
#  16  WFO                 38398 non-null  object
#  17  BEGIN_DATE_TIME     38398 non-null  object
#  18  CZ_TIMEZONE         38398 non-null  object
#  19  END_DATE_TIME       38398 non-null  object
#  20  INJURIES_DIRECT     38398 non-null  int64
#  21  INJURIES_INDIRECT   38398 non-null  int64
#  22  DEATHS_DIRECT       38398 non-null  int64
#  23  DEATHS_INDIRECT     38398 non-null  int64
#  24  DAMAGE_PROPERTY     38398 non-null  object
#  25  DAMAGE_CROPS        38398 non-null  object
#  26  SOURCE              38398 non-null  object
#  27  MAGNITUDE           0 non-null      float64
#  28  MAGNITUDE_TYPE      0 non-null      object
#  29  FLOOD_CAUSE         38398 non-null  object
#  30  CATEGORY            0 non-null      float64
#  31  TOR_F_SCALE         0 non-null      object
#  32  TOR_LENGTH          0 non-null      float64
#  33  TOR_WIDTH           0 non-null      float64
#  34  TOR_OTHER_WFO       0 non-null      object
#  35  TOR_OTHER_CZ_STATE  0 non-null      object
#  36  TOR_OTHER_CZ_FIPS   0 non-null      float64
#  37  TOR_OTHER_CZ_NAME   0 non-null      object
#  38  BEGIN_RANGE         38398 non-null  float64
#  39  BEGIN_AZIMUTH       38398 non-null  object
#  40  BEGIN_LOCATION      38398 non-null  object
#  41  END_RANGE           38398 non-null  float64
#  42  END_AZIMUTH         38398 non-null  object
#  43  END_LOCATION        38398 non-null  object
#  44  BEGIN_LAT           38398 non-null  float64
#  45  BEGIN_LON           38398 non-null  float64
#  46  END_LAT             38398 non-null  float64
#  47  END_LON             38398 non-null  float64
#  48  EPISODE_NARRATIVE   38398 non-null  object
#  49  EVENT_NARRATIVE     38398 non-null  object
#  50  DATA_SOURCE         38398 non-null  object
# dtypes: float64(13), int64(13), object(25)
# memory usage: 14.9+ MB

# %% [markdown]
# ### Flood dataset with selected variables

# %%
flood_dataset=dftot_flood_cleaned[['EVENT_ID','BEGIN_DATE_TIME','END_DATE_TIME','STATE','STATE_FIPS','EVENT_TYPE','CZ_TYPE','CZ_FIPS',
                                   'CZ_NAME','WFO','CZ_TIMEZONE','INJURIES_DIRECT','INJURIES_INDIRECT','DEATHS_DIRECT',
                                   'DEATHS_INDIRECT','DAMAGE_PROPERTY','DAMAGE_CROPS','SOURCE','FLOOD_CAUSE','BEGIN_RANGE',
                                   'BEGIN_AZIMUTH','BEGIN_LOCATION','END_RANGE','END_AZIMUTH','END_LOCATION','BEGIN_LAT',
                                   'BEGIN_LON','END_LAT','END_LON','EPISODE_NARRATIVE','EVENT_NARRATIVE']]

# %% [markdown]
# ### Monetary Conversion of Text Amounts

# %%
# Define a function to convert strings to numbers
def convert_to_number(x):
    # If x is empty, return 0
    if x == "":
        return 0
    # If x ends with K, multiply by 1000
    elif x[-1] == "K":
        return float(x[:-1]) * 1000
    # If x ends with M, multiply by 1000000
    elif x[-1] == "M":
        return float(x[:-1]) * 1000000
    # If x ends with B, multiply by 1000000000
    elif x[-1] == "B":
        return float(x[:-1]) * 1000000000    
    # Otherwise, return x as a float
    else:
        return float(x)

flood_df=flood_dataset.copy()    
# Apply the function to the columns "DAMAGE_PROPERTY" and "DAMAGE_CROPS"
flood_df.loc[:,"DAMAGE_PROPERTY"] = flood_df.loc[:,"DAMAGE_PROPERTY"].apply(convert_to_number)
flood_df.loc[:,"DAMAGE_CROPS"] = flood_df.loc[:,"DAMAGE_CROPS"].apply(convert_to_number)

# %%
flood_df.head(10)
# Out:
#    EVENT_ID     BEGIN_DATE_TIME       END_DATE_TIME          STATE  \
# 0      2161  28-OCT-06 14:00:00  28-OCT-06 16:30:00  MASSACHUSETTS
# 1      4734  16-NOV-06 20:00:00  16-NOV-06 22:00:00       NEW YORK
# 2      3709  16-NOV-06 23:49:00  17-NOV-06 05:28:00       NEW YORK
# 3      3718  17-NOV-06 05:03:00  17-NOV-06 13:56:00       NEW YORK
# 4      3720  17-NOV-06 05:03:00  17-NOV-06 13:56:00       NEW YORK
# 5      2189  28-OCT-06 15:00:00  28-OCT-06 17:00:00    CONNECTICUT
# 6      2162  28-OCT-06 14:00:00  28-OCT-06 16:30:00  MASSACHUSETTS
# 7      3741  17-NOV-06 07:00:00  18-NOV-06 21:30:00       NEW YORK
# 8      9312  14-DEC-06 07:00:00  14-DEC-06 15:00:00         OREGON
# 9      9313  14-DEC-06 07:00:00  15-DEC-06 15:00:00         OREGON
#
#    STATE_FIPS EVENT_TYPE CZ_TYPE  CZ_FIPS      CZ_NAME  WFO  ...  \
# 0        25.0      Flood  County       25      SUFFOLK  BOX  ...
# 1        36.0      Flood  County       43     HERKIMER  ALY  ...
# 2        36.0      Flood  County       57   MONTGOMERY  ALY  ...
# 3        36.0      Flood  County       57   MONTGOMERY  ALY  ...
# 4        36.0      Flood  County       93  SCHENECTADY  ALY  ...
# 5         9.0      Flood  County       15      WINDHAM  BOX  ...
# 6        25.0      Flood  County        5      BRISTOL  BOX  ...
# 7        36.0      Flood  County       43     HERKIMER  ALY  ...
# 8        41.0      Flood  County       57    TILLAMOOK  PQR  ...
# 9        41.0      Flood  County       57    TILLAMOOK  PQR  ...
#
#   BEGIN_LOCATION  END_RANGE  END_AZIMUTH   END_LOCATION  BEGIN_LAT  BEGIN_LON  \
# 0         BOSTON        0.0            N         BOSTON      42.32     -71.07
# 1   LITTLE FALLS        0.0            N   LITTLE FALLS      43.05     -74.87
# 2  ST JOHNSVILLE        9.0           NW  ST JOHNSVILLE      43.09     -74.54
# 3    TRIBES HILL        0.0            N    TRIBES HILL      42.95     -74.30
# 4    SCHENECTADY       17.0           NW    SCHENECTADY      42.97     -73.68
# 5    WILLIMANTIC        0.0            N    WILLIMANTIC      41.72     -72.22
# 6        TAUNTON        0.0            N        TAUNTON      41.90     -71.10
# 7          GRANT        4.0            W          GRANT      43.32     -74.97
# 8      TILLAMOOK        0.0            N      TILLAMOOK      45.45    -123.85
# 9      BATTERSON        0.0            N      BATTERSON      45.73    -123.75
#
#    END_LAT END_LON                                  EPISODE_NARRATIVE  \
# 0    42.32  -71.07  Low pressure intensified rapidly as it tracked...
# 1    43.05  -74.87  A low pressure system developed over the lower...
# 2    43.09  -74.54  A low pressure system developed over the lower...
# 3    42.95  -74.30  A low pressure system developed over the lower...
# 4    42.97  -73.68  A low pressure system developed over the lower...
# 5    41.72  -72.22  Significant urban flooding impacted Windham Co...
# 6    41.90  -71.10  Low pressure intensified rapidly as it tracked...
# 7    43.32  -74.97  A low pressure system developed over the lower...
# 8    45.45 -123.85  A series of very wet Pacific storms brought si...
# 9    45.73 -123.75  A series of very wet Pacific storms brought si...
#
#                                      EVENT_NARRATIVE
# 0  Significant urban flooding was reported throug...
# 1  Flooding caused road closures on Route 5 near ...
# 2  The Mohawk River at Little Falls exceeded its ...
# 3  The Mohawk River at Tribes Hill exceeded its f...
# 4  The Mohawk River at Tribes Hill exceeded its f...
# 5  Significant urban flooding was reported in and...
# 6  Significant urban flooding was reported in Tau...
# 7  The West Canada Creek at Hinckley exceeded its...
# 8  The Wilson River near Tillamook crested at 12....
# 9  The Nehalem River near Foss was above flood st...
#
# [10 rows x 31 columns]

# %%
flood_df.iloc[:,0:10].head(10)
# Out:
#    EVENT_ID     BEGIN_DATE_TIME       END_DATE_TIME          STATE  \
# 0      2161  28-OCT-06 14:00:00  28-OCT-06 16:30:00  MASSACHUSETTS
# 1      4734  16-NOV-06 20:00:00  16-NOV-06 22:00:00       NEW YORK
# 2      3709  16-NOV-06 23:49:00  17-NOV-06 05:28:00       NEW YORK
# 3      3718  17-NOV-06 05:03:00  17-NOV-06 13:56:00       NEW YORK
# 4      3720  17-NOV-06 05:03:00  17-NOV-06 13:56:00       NEW YORK
# 5      2189  28-OCT-06 15:00:00  28-OCT-06 17:00:00    CONNECTICUT
# 6      2162  28-OCT-06 14:00:00  28-OCT-06 16:30:00  MASSACHUSETTS
# 7      3741  17-NOV-06 07:00:00  18-NOV-06 21:30:00       NEW YORK
# 8      9312  14-DEC-06 07:00:00  14-DEC-06 15:00:00         OREGON
# 9      9313  14-DEC-06 07:00:00  15-DEC-06 15:00:00         OREGON
#
#    STATE_FIPS EVENT_TYPE CZ_TYPE  CZ_FIPS      CZ_NAME  WFO
# 0        25.0      Flood  County       25      SUFFOLK  BOX
# 1        36.0      Flood  County       43     HERKIMER  ALY
# 2        36.0      Flood  County       57   MONTGOMERY  ALY
# 3        36.0      Flood  County       57   MONTGOMERY  ALY
# 4        36.0      Flood  County       93  SCHENECTADY  ALY
# 5         9.0      Flood  County       15      WINDHAM  BOX
# 6        25.0      Flood  County        5      BRISTOL  BOX
# 7        36.0      Flood  County       43     HERKIMER  ALY
# 8        41.0      Flood  County       57    TILLAMOOK  PQR
# 9        41.0      Flood  County       57    TILLAMOOK  PQR

# %%
flood_df.iloc[:,10:20].head(10)
# Out:
#   CZ_TIMEZONE  INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# 0       EST-5                0                  0              0
# 1       EST-5                0                  0              0
# 2       EST-5                0                  0              0
# 3       EST-5                0                  0              0
# 4       EST-5                0                  0              0
# 5       EST-5                0                  0              0
# 6       EST-5                0                  0              0
# 7       EST-5                0                  0              0
# 8       PST-8                0                  0              0
# 9       PST-8                0                  0              0
#
#    DEATHS_INDIRECT  DAMAGE_PROPERTY  DAMAGE_CROPS                     SOURCE  \
# 0                0           8000.0           0.0            Broadcast Media
# 1                0              0.0           0.0            Law Enforcement
# 2                0              0.0           0.0       Other Federal Agency
# 3                0              0.0           0.0       Other Federal Agency
# 4                0              0.0           0.0       Other Federal Agency
# 5                0           2000.0           0.0                  Newspaper
# 6                0           5000.0           0.0            Trained Spotter
# 7                0              0.0           0.0       Other Federal Agency
# 8                0              0.0           0.0  Official NWS Observations
# 9                0              0.0           0.0  Official NWS Observations
#
#   FLOOD_CAUSE  BEGIN_RANGE
# 0  Heavy Rain          0.0
# 1  Heavy Rain          0.0
# 2  Heavy Rain          9.0
# 3  Heavy Rain          0.0
# 4  Heavy Rain         17.0
# 5  Heavy Rain          0.0
# 6  Heavy Rain          0.0
# 7  Heavy Rain          4.0
# 8  Heavy Rain          0.0
# 9  Heavy Rain          0.0

# %%
flood_df.iloc[:,20:31].head(10)
# Out:
#   BEGIN_AZIMUTH BEGIN_LOCATION  END_RANGE END_AZIMUTH   END_LOCATION  \
# 0             N         BOSTON        0.0           N         BOSTON
# 1             N   LITTLE FALLS        0.0           N   LITTLE FALLS
# 2            NW  ST JOHNSVILLE        9.0          NW  ST JOHNSVILLE
# 3             N    TRIBES HILL        0.0           N    TRIBES HILL
# 4            NW    SCHENECTADY       17.0          NW    SCHENECTADY
# 5             N    WILLIMANTIC        0.0           N    WILLIMANTIC
# 6             N        TAUNTON        0.0           N        TAUNTON
# 7             W          GRANT        4.0           W          GRANT
# 8             N      TILLAMOOK        0.0           N      TILLAMOOK
# 9             N      BATTERSON        0.0           N      BATTERSON
#
#    BEGIN_LAT  BEGIN_LON  END_LAT  END_LON  \
# 0      42.32     -71.07    42.32   -71.07
# 1      43.05     -74.87    43.05   -74.87
# 2      43.09     -74.54    43.09   -74.54
# 3      42.95     -74.30    42.95   -74.30
# 4      42.97     -73.68    42.97   -73.68
# 5      41.72     -72.22    41.72   -72.22
# 6      41.90     -71.10    41.90   -71.10
# 7      43.32     -74.97    43.32   -74.97
# 8      45.45    -123.85    45.45  -123.85
# 9      45.73    -123.75    45.73  -123.75
#
#                                    EPISODE_NARRATIVE  \
# 0  Low pressure intensified rapidly as it tracked...
# 1  A low pressure system developed over the lower...
# 2  A low pressure system developed over the lower...
# 3  A low pressure system developed over the lower...
# 4  A low pressure system developed over the lower...
# 5  Significant urban flooding impacted Windham Co...
# 6  Low pressure intensified rapidly as it tracked...
# 7  A low pressure system developed over the lower...
# 8  A series of very wet Pacific storms brought si...
# 9  A series of very wet Pacific storms brought si...
#
#                                      EVENT_NARRATIVE
# 0  Significant urban flooding was reported throug...
# 1  Flooding caused road closures on Route 5 near ...
# 2  The Mohawk River at Little Falls exceeded its ...
# 3  The Mohawk River at Tribes Hill exceeded its f...
# 4  The Mohawk River at Tribes Hill exceeded its f...
# 5  Significant urban flooding was reported in and...
# 6  Significant urban flooding was reported in Tau...
# 7  The West Canada Creek at Hinckley exceeded its...
# 8  The Wilson River near Tillamook crested at 12....
# 9  The Nehalem River near Foss was above flood st...

# %%
flood_df.describe(include='all').T
# Out:
#                    count unique  \
# EVENT_ID           38398    NaN
# BEGIN_DATE_TIME    38398  27478
# END_DATE_TIME      38398  25667
# STATE              38398     54
# STATE_FIPS         38398    NaN
# EVENT_TYPE         38398      1
# CZ_TYPE            38398      1
# CZ_FIPS            38398    NaN
# CZ_NAME            38398   1754
# WFO                38398    121
# CZ_TIMEZONE        38398      8
# INJURIES_DIRECT    38398    NaN
# INJURIES_INDIRECT  38398    NaN
# DEATHS_DIRECT      38398    NaN
# DEATHS_INDIRECT    38398    NaN
# DAMAGE_PROPERTY    38398    NaN
# DAMAGE_CROPS       38398    NaN
# SOURCE             38398     33
# FLOOD_CAUSE        38398      7
# BEGIN_RANGE        38398    NaN
# BEGIN_AZIMUTH      38398     16
# BEGIN_LOCATION     38398  13022
# END_RANGE          38398    NaN
# END_AZIMUTH        38398     16
# END_LOCATION       38398  13534
# BEGIN_LAT          38398    NaN
# BEGIN_LON          38398    NaN
# END_LAT            38398    NaN
# END_LON            38398    NaN
# EPISODE_NARRATIVE  38398  10895
# EVENT_NARRATIVE    38398  36411
#
#                                                                  top   freq  \
# EVENT_ID                                                         NaN    NaN
# BEGIN_DATE_TIME                                   01-JUN-19 00:00:00    204
# END_DATE_TIME                                     31-MAY-19 23:59:00    191
# STATE                                                       VIRGINIA   2581
# STATE_FIPS                                                       NaN    NaN
# EVENT_TYPE                                                     Flood  38398
# CZ_TYPE                                                       County  38398
# CZ_FIPS                                                          NaN    NaN
# CZ_NAME                                                   WASHINGTON    469
# WFO                                                              LWX   3289
# CZ_TIMEZONE                                                    EST-5  16548
# INJURIES_DIRECT                                                  NaN    NaN
# INJURIES_INDIRECT                                                NaN    NaN
# DEATHS_DIRECT                                                    NaN    NaN
# DEATHS_INDIRECT                                                  NaN    NaN
# DAMAGE_PROPERTY                                                  NaN    NaN
# DAMAGE_CROPS                                                     NaN    NaN
# SOURCE                                             River/Stream Gage   8333
# FLOOD_CAUSE                                               Heavy Rain  32799
# BEGIN_RANGE                                                      NaN    NaN
# BEGIN_AZIMUTH                                                      N   7507
# BEGIN_LOCATION                                               AUGUSTA    146
# END_RANGE                                                        NaN    NaN
# END_AZIMUTH                                                        N   3899
# END_LOCATION                                                SAN JUAN    131
# BEGIN_LAT                                                        NaN    NaN
# BEGIN_LON                                                        NaN    NaN
# END_LAT                                                          NaN    NaN
# END_LON                                                          NaN    NaN
# EPISODE_NARRATIVE  Heavy rain on saturated soils during the eveni...    110
# EVENT_NARRATIVE         See the event episode narrative for details.     46
#
#                          mean          std      min      25%      50%  \
# EVENT_ID               582043       293802      350   320257   641838
# BEGIN_DATE_TIME           NaN          NaN      NaN      NaN      NaN
# END_DATE_TIME             NaN          NaN      NaN      NaN      NaN
# STATE                     NaN          NaN      NaN      NaN      NaN
# STATE_FIPS            30.8093      17.7727        1       19       29
# EVENT_TYPE                NaN          NaN      NaN      NaN      NaN
# CZ_TYPE                   NaN          NaN      NaN      NaN      NaN
# CZ_FIPS               88.1479      82.9329        1       29       71
# CZ_NAME                   NaN          NaN      NaN      NaN      NaN
# WFO                       NaN          NaN      NaN      NaN      NaN
# CZ_TIMEZONE               NaN          NaN      NaN      NaN      NaN
# INJURIES_DIRECT     0.0027866    0.0930848        0        0        0
# INJURIES_INDIRECT  0.00132819    0.0843099        0        0        0
# DEATHS_DIRECT       0.0105995      0.13643        0        0        0
# DEATHS_INDIRECT    0.00148445    0.0447567        0        0        0
# DAMAGE_PROPERTY        702996   2.1113e+07        0        0        0
# DAMAGE_CROPS          90666.2  3.11265e+06        0        0        0
# SOURCE                    NaN          NaN      NaN      NaN      NaN
# FLOOD_CAUSE               NaN          NaN      NaN      NaN      NaN
# BEGIN_RANGE           2.47898      5.55599        0        1        1
# BEGIN_AZIMUTH             NaN          NaN      NaN      NaN      NaN
# BEGIN_LOCATION            NaN          NaN      NaN      NaN      NaN
# END_RANGE              2.6056      5.49776        0        1        1
# END_AZIMUTH               NaN          NaN      NaN      NaN      NaN
# END_LOCATION              NaN          NaN      NaN      NaN      NaN
# BEGIN_LAT             38.7446      5.01552  13.2555  36.9558  38.9271
# BEGIN_LON            -89.3608      13.6244 -166.512 -95.4795 -87.8509
# END_LAT                38.727      5.00696  13.2567  36.9521  38.9237
# END_LON               -89.346      13.6219 -166.537 -95.4741 -87.8436
# EPISODE_NARRATIVE         NaN          NaN      NaN      NaN      NaN
# EVENT_NARRATIVE           NaN          NaN      NaN      NaN      NaN
#
#                        75%          max
# EVENT_ID            814380  1.09551e+06
# BEGIN_DATE_TIME        NaN          NaN
# END_DATE_TIME          NaN          NaN
# STATE                  NaN          NaN
# STATE_FIPS              42           99
# EVENT_TYPE             NaN          NaN
# CZ_TYPE                NaN          NaN
# CZ_FIPS                127          840
# CZ_NAME                NaN          NaN
# WFO                    NaN          NaN
# CZ_TIMEZONE            NaN          NaN
# INJURIES_DIRECT          0           10
# INJURIES_INDIRECT        0           13
# DEATHS_DIRECT            0           10
# DEATHS_INDIRECT          0            3
# DAMAGE_PROPERTY       1000        2e+09
# DAMAGE_CROPS             0        5e+08
# SOURCE                 NaN          NaN
# FLOOD_CAUSE            NaN          NaN
# BEGIN_RANGE              3          178
# BEGIN_AZIMUTH          NaN          NaN
# BEGIN_LOCATION         NaN          NaN
# END_RANGE                3          157
# END_AZIMUTH            NaN          NaN
# END_LOCATION           NaN          NaN
# BEGIN_LAT          41.7352      66.8385
# BEGIN_LON         -79.8701      144.833
# END_LAT             41.726      66.8329
# END_LON           -79.8652       144.88
# EPISODE_NARRATIVE      NaN          NaN
# EVENT_NARRATIVE        NaN          NaN

# %% [markdown]
# ### Download dataset

# %%
flood_df.to_csv('flood_dataset.csv', index='False')
